# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df1 = df.copy()
df1.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %%
df1.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis = "columns",inplace = True)

# %%
inputs = df1.drop(["Survived"],axis = "columns")
target = df1["Survived"]

# %%
inputs['Sex'] =  inputs['Sex'].map({'male':'1','female':'2'})

# %%
inputs.Age.fillna(inputs.Age.mean(),inplace = True)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(inputs,target,test_size=0.2)

# %%
y_train
# Out:
# 10     1
# 759    1
# 784    0
# 529    0
# 108    0
#       ..
# 338    1
# 617    0
# 138    0
# 161    1
# 630    1
# Name: Survived, Length: 712, dtype: int64

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(x_train,x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.fit(x_train,x_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py:224, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     221 self.n_outputs_ = y.shape[1]
#     223 if is_classification:
# --> 224     check_classification_targets(y)
#     225     y = np.copy(y)
#     227     self.classes_ = []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\multiclass.py:199, in check_classification_targets(y)
#     187 def check_classification_targets(y):
#     188     """Ensure that target y is of a non-regression type.
#     189
#     190     Only the following target types (as defined in type_of_target) are allowed:
#    (...)
#     197         Target values.
#     198     """
# --> 199     y_type = type_of_target(y, input_name="y")
#     200     if y_type not in [
#     201         "binary",
#     202         "multiclass",
#    (...)
#     205         "multilabel-sequences",
#     206     ]:
#     207         raise ValueError("Unknown label type: %r" % y_type)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\multiclass.py:298, in type_of_target(y, input_name)
#     295 if sparse_pandas:
#     296     raise ValueError("y cannot be class 'SparseSeries' or 'SparseArray'")
# --> 298 if is_multilabel(y):
#     299     return "multilabel-indicator"
#     301 # DeprecationWarning will be replaced by ValueError, see NEP 34
#     302 # https://numpy.org/neps/nep-0034-infer-dtype-is-object.html
#     303 # We therefore catch both deprecation (NumPy < 1.24) warning and
#     304 # value error (NumPy >= 1.24).
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\multiclass.py:180, in is_multilabel(y)
#     174     return (
#     175         len(y.data) == 0
#     176         or (labels.size == 1 or (labels.size == 2) and (0 in labels))
#     177         and (y.dtype.kind in "biu" or _is_integral_float(labels))  # bool, int, uint
#     178     )
#     179 else:
# --> 180     labels = xp.unique_values(y)
#     182     return len(labels) < 3 and (
#     183         y.dtype.kind in "biu" or _is_integral_float(labels)  # bool, int, uint
#     184     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py:84, in _NumPyApiWrapper.unique_values(self, x)
#      83 def unique_values(self, x):
# ---> 84     return numpy.unique(x)
#
# File <__array_function__ internals>:200, in unique(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'str' and 'int'
